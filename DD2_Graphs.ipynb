# %% [markdown]
# #Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

# %% [markdown]
# #The first graph ( HPWL vs Temperature)

# %% [markdown]
# ##d0

# %%
d0_df=pd.read_csv('annealing_datad0.csv')

# %%
d0_df
# Out:
#      Iteration  CurrentTemperature  TotalHPWL
# 0            0        49000.000000        110
# 1            1        46550.000000         89
# 2            2        44222.500000        103
# 3            3        42011.400000         87
# 4            4        39910.800000         73
# ..         ...                 ...        ...
# 409        409            0.000038         36
# 410        410            0.000036         36
# 411        411            0.000034         36
# 412        412            0.000033         36
# 413        413            0.000031         36
#
# [414 rows x 3 columns]

# %%
fig = px.line(d0_df
              , x='CurrentTemperature', y='TotalHPWL', title='Annealing Progress')

# %%
fig = px.line(d0_df, x='CurrentTemperature', y='TotalHPWL', title='Annealing Progress',line_shape='linear')
interpolated_line = np.linspace( d0_df['TotalHPWL'].iloc[0],d0_df['TotalHPWL'].iloc[-1], len(d0_df))
fig.add_scatter(x=d0_df['CurrentTemperature'], y=interpolated_line, mode='lines', name='Interpolated Line')
fig.update_layout(
    xaxis_title='Current Temperature',
    yaxis_title='Total HPWL',
    showlegend=True
)
fig.update_xaxes(autorange="reversed")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


plt.plot(d0_df['CurrentTemperature'], d0_df['TotalHPWL'], label='Annealing Progress')

interpolated_line = np.linspace(d0_df['TotalHPWL'].iloc[0], d0_df['TotalHPWL'].iloc[-1], len(d0_df))
plt.plot(d0_df['CurrentTemperature'], interpolated_line, label='Interpolated Line', linestyle='--')

plt.title('Annealing Progress')
plt.xlabel('Current Temperature')
plt.ylabel('Total HPWL')
plt.legend()
plt.gca().invert_xaxis()
plt.xscale('log')
plt.show()

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##d1

# %%
d1_df=pd.read_csv('annealing_datad1.csv')

# %%
d1_df
# Out:
#      Iteration  CurrentTemperature  TotalHPWL
# 0            0        87500.000000        182
# 1            1        83125.000000        155
# 2            2        78968.800000        164
# 3            3        75020.300000        191
# 4            4        71269.300000        172
# ..         ...                 ...        ...
# 424        424            0.000031         71
# 425        425            0.000030         68
# 426        426            0.000028         68
# 427        427            0.000027         66
# 428        428            0.000026         66
#
# [429 rows x 3 columns]

# %%
fig = px.line(d1_df, x='CurrentTemperature', y='TotalHPWL', title='Annealing Progress',line_shape='linear')
interpolated_line = np.linspace( d1_df['TotalHPWL'].iloc[0],d1_df['TotalHPWL'].iloc[-1], len(d1_df))
fig.add_scatter(x=d1_df['CurrentTemperature'], y=interpolated_line, mode='lines', name='Interpolated Line')
fig.update_layout(
    xaxis_title='Current Temperature',
    yaxis_title='Total HPWL',
    showlegend=True
)
fig.update_xaxes(autorange="reversed")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


plt.plot(d1_df['CurrentTemperature'], d1_df['TotalHPWL'], label='Annealing Progress')


interpolated_line = np.linspace(d1_df['TotalHPWL'].iloc[0], d1_df['TotalHPWL'].iloc[-1], len(d1_df))
plt.plot(d1_df['CurrentTemperature'], interpolated_line, label='Interpolated Line', linestyle='--')


plt.title('Annealing Progress')
plt.xlabel('Current Temperature')
plt.ylabel('Total HPWL')
plt.xscale('log')
plt.legend()
plt.gca().invert_xaxis()
plt.show()

# %% [markdown]
# ##d2

# %%
d2_df=pd.read_csv('annealing_datad2.csv')

# %%
d2_df
# Out:
#      Iteration  CurrentTemperature  TotalHPWL
# 0            0        1.971500e+06       3892
# 1            1        1.872920e+06       3887
# 2            2        1.779280e+06       3838
# 3            3        1.690310e+06       3811
# 4            4        1.605800e+06       3971
# ..         ...                 ...        ...
# 461        461        1.060180e-04       1036
# 462        462        1.007170e-04       1032
# 463        463        9.568110e-05       1028
# 464        464        9.089700e-05       1026
# 465        465        8.635220e-05       1025
#
# [466 rows x 3 columns]

# %%
fig = px.line(d2_df, x='CurrentTemperature', y='TotalHPWL', title='Annealing Progress',line_shape='linear')
interpolated_line = np.linspace( d2_df['TotalHPWL'].iloc[0],d2_df['TotalHPWL'].iloc[-1], len(d2_df))
fig.add_scatter(x=d2_df['CurrentTemperature'], y=interpolated_line, mode='lines', name='Interpolated Line')
fig.update_layout(
    xaxis_title='Current Temperature',
    yaxis_title='Total HPWL',
    showlegend=True
)
fig.update_xaxes(autorange="reversed")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


plt.plot(d2_df['CurrentTemperature'], d2_df['TotalHPWL'], label='Annealing Progress')


interpolated_line = np.linspace(d2_df['TotalHPWL'].iloc[0], d2_df['TotalHPWL'].iloc[-1], len(d2_df))
plt.plot(d2_df['CurrentTemperature'], interpolated_line, label='Interpolated Line', linestyle='--')


plt.title('Annealing Progress')
plt.xlabel('Current Temperature')
plt.ylabel('Total HPWL')
plt.xscale('log')
plt.legend()
plt.gca().invert_xaxis()
plt.show()

# %% [markdown]
# ##d3

# %%
d3_df=pd.read_csv('annealing_datad3.csv')

# %%
d3_df
# Out:
#      Iteration  CurrentTemperature  TotalHPWL
# 0            0        1.841000e+06       3840
# 1            1        1.748950e+06       3607
# 2            2        1.661500e+06       3666
# 3            3        1.578430e+06       3668
# 4            4        1.499510e+06       3597
# ..         ...                 ...        ...
# 459        459        1.096950e-04        897
# 460        460        1.042110e-04        897
# 461        461        9.900010e-05        897
# 462        462        9.405010e-05        897
# 463        463        8.934760e-05        897
#
# [464 rows x 3 columns]

# %%
fig = px.line(d3_df, x='CurrentTemperature', y='TotalHPWL', title='Annealing Progress',line_shape='linear')
interpolated_line = np.linspace( d3_df['TotalHPWL'].iloc[0],d3_df['TotalHPWL'].iloc[-1], len(d3_df))
fig.add_scatter(x=d3_df['CurrentTemperature'], y=interpolated_line, mode='lines', name='Interpolated Line')
fig.update_layout(
    xaxis_title='Current Temperature',
    yaxis_title='Total HPWL',
    showlegend=True
)
fig.update_xaxes(autorange="reversed")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


plt.plot(d3_df['CurrentTemperature'], d3_df['TotalHPWL'], label='Annealing Progress')


interpolated_line = np.linspace(d3_df['TotalHPWL'].iloc[0], d3_df['TotalHPWL'].iloc[-1], len(d3_df))
plt.plot(d3_df['CurrentTemperature'], interpolated_line, label='Interpolated Line', linestyle='--')


plt.title('Annealing Progress')
plt.xlabel('Current Temperature')
plt.ylabel('Total HPWL')
plt.xscale('log')
plt.legend()
plt.gca().invert_xaxis()
plt.show()

# %% [markdown]
# ##t1

# %%
t1_df=pd.read_csv('annealing_datat1.csv')

# %%
t1_df
# Out:
#      Iteration  CurrentTemperature  TotalHPWL
# 0            0        3.407500e+06       6849
# 1            1        3.237120e+06       6988
# 2            2        3.075270e+06       6941
# 3            3        2.921510e+06       6762
# 4            4        2.775430e+06       6776
# ..         ...                 ...        ...
# 468        468        1.279630e-04       2081
# 469        469        1.215640e-04       2079
# 470        470        1.154860e-04       2075
# 471        471        1.097120e-04       2072
# 472        472        1.042260e-04       2064
#
# [473 rows x 3 columns]

# %%
fig = px.line(t1_df, x='CurrentTemperature', y='TotalHPWL', title='Annealing Progress',line_shape='linear')
interpolated_line = np.linspace( t1_df['TotalHPWL'].iloc[0],t1_df['TotalHPWL'].iloc[-1], len(t1_df))
fig.add_scatter(x=t1_df['CurrentTemperature'], y=interpolated_line, mode='lines', name='Interpolated Line')
fig.update_layout(
    xaxis_title='Current Temperature',
    yaxis_title='Total HPWL',
    showlegend=True
)
fig.update_xaxes(autorange="reversed")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


plt.plot(t1_df['CurrentTemperature'], t1_df['TotalHPWL'], label='Annealing Progress')


interpolated_line = np.linspace(t1_df['TotalHPWL'].iloc[0], t1_df['TotalHPWL'].iloc[-1], len(t1_df))
plt.plot(t1_df['CurrentTemperature'], interpolated_line, label='Interpolated Line', linestyle='--')


plt.title('Annealing Progress')
plt.xlabel('Current Temperature')
plt.ylabel('Total HPWL')
plt.xscale('log')
plt.legend()
plt.gca().invert_xaxis()
plt.show()

# %% [markdown]
# ##t2

# %%
t2_df=pd.read_csv('annealing_datat2.csv')

# %%
t2_df
# Out:
#      Iteration  CurrentTemperature  TotalHPWL
# 0            0        2.304500e+07      45039
# 1            1        2.189280e+07      45384
# 2            2        2.079810e+07      45694
# 3            3        1.975820e+07      45913
# 4            4        1.877030e+07      46689
# ..         ...                 ...        ...
# 485        485        3.618470e-04       5920
# 486        486        3.437550e-04       5889
# 487        487        3.265670e-04       5892
# 488        488        3.102390e-04       5857
# 489        489        2.947270e-04       5828
#
# [490 rows x 3 columns]

# %%
fig = px.line(t2_df, x='CurrentTemperature', y='TotalHPWL', title='Annealing Progress',line_shape='linear')
interpolated_line = np.linspace( t2_df['TotalHPWL'].iloc[0],t2_df['TotalHPWL'].iloc[-1], len(t2_df))
fig.add_scatter(x=t2_df['CurrentTemperature'], y=interpolated_line, mode='lines', name='Interpolated Line')
fig.update_layout(
    xaxis_title='Current Temperature',
    yaxis_title='Total HPWL',
    showlegend=True
)
fig.update_xaxes(autorange="reversed")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


plt.plot(t2_df['CurrentTemperature'], t2_df['TotalHPWL'], label='Annealing Progress')


interpolated_line = np.linspace(t2_df['TotalHPWL'].iloc[0], t2_df['TotalHPWL'].iloc[-1], len(t2_df))
plt.plot(t2_df['CurrentTemperature'], interpolated_line, label='Interpolated Line', linestyle='--')


plt.title('Annealing Progress')
plt.xlabel('Current Temperature')
plt.ylabel('Total HPWL')
plt.xscale('log')
plt.legend()
plt.gca().invert_xaxis()
plt.show()

# %% [markdown]
# ##t3

# %%
t3_df=pd.read_csv('annealing_datat3.csv')

# %%
t3_df
# Out:
#      Iteration  CurrentTemperature  TotalHPWL
# 0            0        2.174400e+07      43414
# 1            1        2.065680e+07      43775
# 2            2        1.962400e+07      43374
# 3            3        1.864280e+07      43931
# 4            4        1.771060e+07      43654
# ..         ...                 ...        ...
# 494        494        2.151790e-04      11393
# 495        495        2.044200e-04      11559
# 496        496        1.941990e-04      11491
# 497        497        1.844890e-04      11442
# 498        498        1.752650e-04      11428
#
# [499 rows x 3 columns]

# %%
fig = px.line(t3_df, x='CurrentTemperature', y='TotalHPWL', title='Annealing Progress',line_shape='linear')
interpolated_line = np.linspace( t3_df['TotalHPWL'].iloc[0],t3_df['TotalHPWL'].iloc[-1], len(t3_df))
fig.add_scatter(x=t3_df['CurrentTemperature'], y=interpolated_line, mode='lines', name='Interpolated Line')
fig.update_layout(
    xaxis_title='Current Temperature',
    yaxis_title='Total HPWL',
    showlegend=True
)
fig.update_xaxes(autorange="reversed")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


plt.plot(t3_df['CurrentTemperature'], t3_df['TotalHPWL'], label='Annealing Progress')


interpolated_line = np.linspace(t3_df['TotalHPWL'].iloc[0], t3_df['TotalHPWL'].iloc[-1], len(t3_df))
plt.plot(t3_df['CurrentTemperature'], interpolated_line, label='Interpolated Line', linestyle='--')


plt.title('Annealing Progress')
plt.xlabel('Current Temperature')
plt.ylabel('Total HPWL')
plt.xscale('log')
plt.legend()
plt.gca().invert_xaxis()
plt.show()

# %% [markdown]
# #Graph 2 (Cooling factor vs final cost)

# %% [markdown]
# ##d0

# %%
d0_df2=pd.read_csv('annealing_data_graph2_d0.csv')

# %%
d0_df2
# Out:
#     Iteration  cooling factor  TotalHPWL
# 0           0    9.000000e-01         80
# 1           1    8.500000e-01         99
# 2           2    8.000000e-01         88
# 3           3    7.500000e-01         97
# 4           4    7.000000e-01         81
# 5           5    6.500000e-01         88
# 6           6    6.000000e-01         81
# 7           7    5.500000e-01         90
# 8           8    5.000000e-01        103
# 9           9    4.500000e-01         92
# 10         10    4.000000e-01        107
# 11         11    3.500000e-01         82
# 12         12    3.000000e-01         93
# 13         13    2.500000e-01         84
# 14         14    2.000000e-01         95
# 15         15    1.500000e-01         90
# 16         16    1.000000e-01         99
# 17         17    5.000000e-02         83
# 18         18   -3.191890e-16         91

# %%
fig = px.line(d0_df2, x='cooling factor', y='TotalHPWL', title='Annealing Progress',line_shape='linear')
interpolated_line = np.linspace( d0_df2['TotalHPWL'].iloc[0],d0_df2['TotalHPWL'].iloc[-1], len(d0_df2))
fig.add_scatter(x=d0_df2['cooling factor'], y=interpolated_line, mode='lines', name='Interpolated Line')
fig.update_layout(
    xaxis_title='cooling factor',
    yaxis_title='Total HPWL',
    showlegend=True
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##d1

# %%
d1_df2=pd.read_csv('annealing_data_graph2_d1.csv')

# %%
d1_df2
# Out:
#     Iteration  cooling factor  TotalHPWL
# 0           0    9.000000e-01        160
# 1           1    8.500000e-01        167
# 2           2    8.000000e-01        172
# 3           3    7.500000e-01        153
# 4           4    7.000000e-01        189
# 5           5    6.500000e-01        185
# 6           6    6.000000e-01        182
# 7           7    5.500000e-01        188
# 8           8    5.000000e-01        185
# 9           9    4.500000e-01        169
# 10         10    4.000000e-01        179
# 11         11    3.500000e-01        188
# 12         12    3.000000e-01        167
# 13         13    2.500000e-01        167
# 14         14    2.000000e-01        188
# 15         15    1.500000e-01        140
# 16         16    1.000000e-01        169
# 17         17    5.000000e-02        178
# 18         18   -3.191890e-16        168

# %%
fig = px.line(d1_df2, x='cooling factor', y='TotalHPWL', title='Annealing Progress',line_shape='linear')
interpolated_line = np.linspace( d1_df2['TotalHPWL'].iloc[0],d1_df2['TotalHPWL'].iloc[-1], len(d1_df2))
fig.add_scatter(x=d1_df2['cooling factor'], y=interpolated_line, mode='lines', name='Interpolated Line')
fig.update_layout(
    xaxis_title='cooling factor',
    yaxis_title='Total HPWL',
    showlegend=True
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##d2

# %%
d2_df2=pd.read_csv('annealing_data_graph2_d2.csv')

# %%
d2_df2
# Out:
#     Iteration  cooling factor  TotalHPWL
# 0           0    9.000000e-01       3816
# 1           1    8.500000e-01       4022
# 2           2    8.000000e-01       3916
# 3           3    7.500000e-01       3800
# 4           4    7.000000e-01       3927
# 5           5    6.500000e-01       3936
# 6           6    6.000000e-01       3889
# 7           7    5.500000e-01       3932
# 8           8    5.000000e-01       3938
# 9           9    4.500000e-01       3848
# 10         10    4.000000e-01       3901
# 11         11    3.500000e-01       3881
# 12         12    3.000000e-01       3926
# 13         13    2.500000e-01       3905
# 14         14    2.000000e-01       4032
# 15         15    1.500000e-01       3915
# 16         16    1.000000e-01       3793
# 17         17    5.000000e-02       3955
# 18         18   -3.191890e-16       3985

# %%
fig = px.line(d2_df2, x='cooling factor', y='TotalHPWL', title='Annealing Progress',line_shape='linear')
interpolated_line = np.linspace( d2_df2['TotalHPWL'].iloc[0],d2_df2['TotalHPWL'].iloc[-1], len(d2_df2))
fig.add_scatter(x=d2_df2['cooling factor'], y=interpolated_line, mode='lines', name='Interpolated Line')
fig.update_layout(
    xaxis_title='cooling factor',
    yaxis_title='Total HPWL',
    showlegend=True
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##d3

# %%
d3_df2=pd.read_csv('annealing_data_graph2_d3.csv')

# %%
d3_df2
# Out:
#     Iteration  cooling factor  TotalHPWL
# 0           0    9.000000e-01       3463
# 1           1    8.500000e-01       3641
# 2           2    8.000000e-01       3668
# 3           3    7.500000e-01       3850
# 4           4    7.000000e-01       3593
# 5           5    6.500000e-01       3535
# 6           6    6.000000e-01       3539
# 7           7    5.500000e-01       3667
# 8           8    5.000000e-01       3526
# 9           9    4.500000e-01       3629
# 10         10    4.000000e-01       3652
# 11         11    3.500000e-01       3542
# 12         12    3.000000e-01       3677
# 13         13    2.500000e-01       3734
# 14         14    2.000000e-01       3504
# 15         15    1.500000e-01       3473
# 16         16    1.000000e-01       3669
# 17         17    5.000000e-02       3573
# 18         18   -3.191890e-16       3520

# %%
fig = px.line(d3_df2, x='cooling factor', y='TotalHPWL', title='Annealing Progress',line_shape='linear')
interpolated_line = np.linspace( d3_df2['TotalHPWL'].iloc[0],d3_df2['TotalHPWL'].iloc[-1], len(d3_df2))
fig.add_scatter(x=d3_df2['cooling factor'], y=interpolated_line, mode='lines', name='Interpolated Line')
fig.update_layout(
    xaxis_title='cooling factor',
    yaxis_title='Total HPWL',
    showlegend=True
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##t1

# %%
t1_df2=pd.read_csv('annealing_data_graph2_t1.csv')

# %%
t1_df2
# Out:
#     Iteration  cooling factor  TotalHPWL
# 0           0    9.000000e-01       6987
# 1           1    8.500000e-01       6921
# 2           2    8.000000e-01       6706
# 3           3    7.500000e-01       6984
# 4           4    7.000000e-01       6868
# 5           5    6.500000e-01       6839
# 6           6    6.000000e-01       6881
# 7           7    5.500000e-01       6892
# 8           8    5.000000e-01       7065
# 9           9    4.500000e-01       6708
# 10         10    4.000000e-01       6873
# 11         11    3.500000e-01       6881
# 12         12    3.000000e-01       6817
# 13         13    2.500000e-01       6896
# 14         14    2.000000e-01       6888
# 15         15    1.500000e-01       7021
# 16         16    1.000000e-01       6694
# 17         17    5.000000e-02       6830
# 18         18   -3.191890e-16       7006

# %%
fig = px.line(t1_df2, x='cooling factor', y='TotalHPWL', title='Annealing Progress',line_shape='linear')
interpolated_line = np.linspace( t1_df2['TotalHPWL'].iloc[0],t1_df2['TotalHPWL'].iloc[-1], len(t1_df2))
fig.add_scatter(x=t1_df2['cooling factor'], y=interpolated_line, mode='lines', name='Interpolated Line')
fig.update_layout(
    xaxis_title='cooling factor',
    yaxis_title='Total HPWL',
    showlegend=True
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##t2

# %%
t2_df2=pd.read_csv('annealing_data_graph2_t2.csv')

# %%
t2_df2
# Out:
#     Iteration  cooling factor  TotalHPWL
# 0           0    9.000000e-01      45335
# 1           1    8.500000e-01      46960
# 2           2    8.000000e-01      45123
# 3           3    7.500000e-01      46605
# 4           4    7.000000e-01      45286
# 5           5    6.500000e-01      46209
# 6           6    6.000000e-01      46367
# 7           7    5.500000e-01      45898
# 8           8    5.000000e-01      45839
# 9           9    4.500000e-01      46551
# 10         10    4.000000e-01      46722
# 11         11    3.500000e-01      46870
# 12         12    3.000000e-01      45332
# 13         13    2.500000e-01      45800
# 14         14    2.000000e-01      46216
# 15         15    1.500000e-01      45213
# 16         16    1.000000e-01      45920
# 17         17    5.000000e-02      46189
# 18         18   -3.191890e-16      45524

# %%
fig = px.line(t2_df2, x='cooling factor', y='TotalHPWL', title='Annealing Progress',line_shape='linear')
interpolated_line = np.linspace( t2_df2['TotalHPWL'].iloc[0],t2_df2['TotalHPWL'].iloc[-1], len(t2_df2))
fig.add_scatter(x=t2_df2['cooling factor'], y=interpolated_line, mode='lines', name='Interpolated Line')
fig.update_layout(
    xaxis_title='cooling factor',
    yaxis_title='Total HPWL',
    showlegend=True
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##t3

# %%
t3_df2=pd.read_csv('annealing_data_graph2_t3.csv')

# %%
t3_df2
# Out:
#     Iteration  cooling factor  TotalHPWL
# 0           0    9.000000e-01      43136
# 1           1    8.500000e-01      43559
# 2           2    8.000000e-01      43003
# 3           3    7.500000e-01      43451
# 4           4    7.000000e-01      43784
# 5           5    6.500000e-01      43761
# 6           6    6.000000e-01      44023
# 7           7    5.500000e-01      43379
# 8           8    5.000000e-01      43463
# 9           9    4.500000e-01      43591
# 10         10    4.000000e-01      42972
# 11         11    3.500000e-01      43403
# 12         12    3.000000e-01      43128
# 13         13    2.500000e-01      43190
# 14         14    2.000000e-01      43236
# 15         15    1.500000e-01      43637
# 16         16    1.000000e-01      43568
# 17         17    5.000000e-02      43681
# 18         18   -3.191890e-16      43697

# %%
fig = px.line(t3_df2, x='cooling factor', y='TotalHPWL', title='Annealing Progress',line_shape='linear')
interpolated_line = np.linspace( t3_df2['TotalHPWL'].iloc[0],t3_df2['TotalHPWL'].iloc[-1], len(t3_df2))
fig.add_scatter(x=t3_df2['cooling factor'], y=interpolated_line, mode='lines', name='Interpolated Line')
fig.update_layout(
    xaxis_title='cooling factor',
    yaxis_title='Total HPWL',
    showlegend=True
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
